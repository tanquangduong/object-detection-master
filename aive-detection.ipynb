# %% [markdown]
# # AIVE - VIDEO DETECTION CHALLENGE
# """
# Home Exercise
# Given the Dior - Eau de Parfum commercial, use any existing algorithms to generate a video that shows and track the existence of humans within the video by drawing boxes around them for each frame. For different humans, different colors must be used.
#
# Expected Results:
# A video that has the dior commercial, with boxes around each person, and runnable code (in the form of a repo with a good packaging) that can reproduce that video.
# """
# # Needed packages/versions
# Python 3.7.6 or later (I use Python 3.7.13)
#
# pytube==12.0.0
# moviepy==1.0.3
# tensorflow==2.4.0
# tensorflow-gpu==2.4.0
# keras==2.4.3
# numpy==1.19.3
# pillow==7.0.0
# scipy==1.4.1
# h5py==2.10.0
# matplotlib==3.3.2
# opencv-python
# keras-resnet==0.2.0
# imageai==2.1.6

# %% [markdown]
# # Importing required libraries

# %%
# Importing required libraies
import os
import pytube
import cv2 as cv
from imageai.Detection import ObjectDetection
from moviepy.editor import VideoFileClip, AudioFileClip
import time
import numpy as np
from scipy.spatial import distance

# %% [markdown]
# # Initialize Parameters and Detection models

# %%
# Youtube url, i.e. marketing video of Dior commercial
VIDEO_URL = "https://www.youtube.com/watch?v=h4s0llOpKrU"

# Directory to save the downloaded video
VIDEO_IN_PATH = 'video_in'

# Directory to save video frame
VIDEO_OUT_PATH = 'video_out'

# Directory to save the audi file
AUDIO_PATH = 'audio'

# Audio fime name
AUDIO_NAME = 'dior_audio'

# Audio fime extension
AUDIO_EXT = '.mp3'

# Detection model path
MODEL_PATH = 'models/resnet50_coco_best_v2.1.0.h5'  # RetinaNet
# MODEL_PATH = 'models/yolo.h5' # Yolo Net
# MODEL_PATH = 'models/yolo-tiny.h5' # Yolo Tiny Net

# Output video name WITHOUT audio
OUT_VIDEO_NAME = 'dior_box_NO_music_center'

# Output video name WITH audio
OUT_VIDEO_MUSIC_NAME = 'dior_box_music_center'

# Output video extension '.mp4' or '.avi'
OUT_VIDEO_EXT = '.mp4'

# Color list
COLORS = [(255, 0, 0), (0, 255, 0), (0, 0, 255), (255, 0, 255), (0, 255, 255), (255, 50, 0), (50, 255, 0), (50, 0, 255)]

# ----- Other method to generate Color list at scale -----
# rgb_pixel = list(range(0,255,50))
# random.shuffle(rgb_pixel)
# COLORS = list(product(rgb_pixel,rgb_pixel,rgb_pixel))
# random.shuffle(COLORS)

# Get current directory of the python file
execution_path = os.getcwd()

# load detector from ObjectDetection class
detector = ObjectDetection()

# Set ReninaNet for video detection
detector.setModelTypeAsRetinaNet()

# Load RetinaNet model
detector.setModelPath(os.path.join(execution_path, MODEL_PATH))
detector.loadModel()

# Customize Object: Only detect 'person' object
custom_objects = detector.CustomObjects(person=True)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# # Build Utils functions

# %%
"""
This is the utils file of 'aive' package. It includes the following functions:
- create_dir
- download_youtube_video
- extract_audio_from_video
- draw_boxes
- render_video_detection
- render_video_music
"""
# Function to create a directory to save downloaded video
def create_dir(dir_name):
    """ Create a directory if not existed.

    :param dir_name: directory name

    :returns: A new created directory
    """
    if not os.path.exists(dir_name):
        os.mkdir(dir_name)


# Download youtube video from url
def download_youtube_video(url, download_dir):
    """ Download youtube video from video url

    :param
        url_path: url path of the video
        download_dir: path to the download directory

    :returns:
        video_path: (str) path to the downloaded video
    """
    # Load Youtube url into pytube
    youtube = pytube.YouTube(url)

    # Set Streams resolution
    video = youtube.streams.get_highest_resolution()

    # Start downloading youtude video
    video.download(download_dir)

    # Get a list of video names
    video_files = os.listdir(download_dir)

    # Get video name
    video_name = video_files[0]

    # Get video path
    video_path = os.path.join(download_dir, video_name)

    # Print downloaded video path
    print('Video file is saved at: {}'.format(video_path))

    return video_path


# Extract audio from video
def extract_audio_from_video(video_file, audio_path):
    """ Extract audio from video using MoviePy library
    that uses `ffmpeg` under the hood

    :param
        video_file: path to the video file
        output_ext: audio output extension

    :returns: audio file is saved in the same folder of video file
    """
    # Get Clip file
    clip = VideoFileClip(video_file)

    # Save audio file
    clip.audio.write_audiofile(audio_path)

    print('Audio file is saved at: {}'.format(audio_path))


# Function to draw all detected boxes over the video frame
def draw_boxes(image, box_points, colors):
    """ Draw rectangle box for each object detection.
    Different detection has different box color.
    This function is generalized for as many as detected objects. The color
    list is now randomly choice in function of the number of detected object.

    :param
        image: video frame under ndarray

        box_points: A list of box coordinate tuples for each detection. Example: [(20,30,50,60),(15,35,40,65)]

    :returns image under ndarray
    """

    for i, box in enumerate(box_points):
        # It is ok now for the Dior video in term of box color, but if the video has a lot of people detection, then
        # 'colors' should be genereated at scale as many as object detection.
        if i <= len(colors) - 1:
            # Get coordinates of each box for each detection
            xmin, ymin, xmax, ymax = box

            # Draw box with OpenCV
            cv.rectangle(image, (xmin, ymin), (xmax, ymax), colors[i], 2)

    return image

def convert_to_center(box):
    """Changes the box format to center

    Arguments:
      boxes: [x1,y1,x2,y2] -> [left,top,right,bottom]

    Returns:
      find center of the box
    """
    x_center = int((box[0] + box[2])/2)
    y_center = int((box[1] + box[3])/2)
#     width = box[2] - box[0]
#     height = box[3] - box[1]
    return (x_center, y_center)


def render_video_detection(video_path, output_path, detector, custom_objects, colors, ext='.mp4'):
    """ Make object detection on each frame extracted from the video.
    Render processed frames into the output video.
    Function actually supports only .mp4 and .avi as output extension. Default is .mp4

    :param
        video_path: Path to the input video
        output_path: Path to the output video without extension
        detector: detection model
        custom_objects: ex. only 'person'
        box_colors: a list of rgb color for each bounding box
        ext: video extension
    :returns video with detected objects on each frame

    """

    # Set starting time
    start_time = time.time()

    # Capture video with OpenCV
    input_video = cv.VideoCapture(video_path)

    # Get video FPS
    fps = input_video.get(cv.CAP_PROP_FPS)

    # Get frame width and frame height
    frame_width = int(input_video.get(3))
    frame_height = int(input_video.get(4))

    # Set parameter for video encoder, adapting to the desired video extension, i.e. '.mp4' or '.avi'
    if ext == '.avi':
        # Create output video path
        output_video_filepath = output_path + ext
        output_video = cv.VideoWriter(output_video_filepath,
                                      cv.VideoWriter_fourcc('M', 'J', 'P', 'G'),
                                      fps,
                                      (frame_width, frame_height)
                                      )
    else:  # .mp4
        # Create output video path
        output_video_filepath = output_path + '.mp4'
        output_video = cv.VideoWriter(output_video_filepath,
                                      cv.VideoWriter_fourcc(*'mp4v'),
                                      fps,
                                      (frame_width, frame_height)
                                      )

    # initialize video reading status
    success = True
    count = 0
    image_center = (frame_width/2, frame_height/2)

    # read video from the first to the last frame
    while success:

        # read each frame, return status 'success' and video frame
        success, frame = input_video.read()
        
       
        # if there is still frame to read
        if success:
            # Model prediction: Detect only custom objects, i.e. person.
            _, detections = detector.detectCustomObjectsFromImage(custom_objects=custom_objects,
                                                                  input_image=frame,
                                                                  input_type="array",
                                                                  output_type="array",
                                                                  minimum_percentage_probability=50,
                                                                  display_percentage_probability=False,
                                                                  display_object_name=False)

            # Create a list of box coordinates of each detection
            box_points = [detection['box_points'] for detection in detections]
            
            num_box = len(box_points)

            if num_box == 0:
                detected_frame_array = frame
                
            elif num_box == 1:
                # Draw the rectanges over each frame. Different box color for each person
                detected_frame_array = draw_boxes(frame, box_points, colors)

            else:
                # In this case of study, choosing 2 human detections that have highest probabilities
                perc_proba = [detection['percentage_probability'] for detection in detections]
                box_points = [box_points[i] for i in np.argsort(perc_proba)[::-1]]
                box_points = box_points[:2]
                
                # Convert box into its center
                center_boxes = [convert_to_center(b) for b in box_points]
                
                # Calculate a list of distanced from the box center and the image center
                dist_center = [distance.euclidean(cb, image_center) for cb in center_boxes]
                
                # Sort the 'box_points' that gives the disctance to center in an ascending order  
                box_points_sorted = [box_points[i] for i in np.argsort(dist_center)]
                
                # Draw the rectanges over each frame. Different box color for each person
                detected_frame_array = draw_boxes(frame, box_points_sorted, colors)
                
            # Write detected frame array into output video
            output_video.write(detected_frame_array)

            # Print # frame being processing
            count += 1
            print("Frame: {} is processed.".format(count))
            print('----------------------')

    # Finished. Release input and output video
    input_video.release()
    output_video.release()

    # Print finish status and the processing time
    print("Your processed video WITHOUT music is saved at: {}".format(output_video_filepath))
    print("Rendering Video-detection is finished in {} minutes.".format(round((time.time() - start_time) / 60, 2)))
    return detections


def render_video_music(video_path, audio_path, combined_video_path):
    """ Render object-detected video with its original audio.

    :param
        video_path: Path to the processed video with object detection
        audio_path: Path to audio file
        combined_video_path: Path to save final video with audio
    :returns Final video with detected objects on each frame and its audio

    """

    # loading video dsa gfg intro video
    clip = VideoFileClip(video_path)

    # loading audio file
    audioclip = AudioFileClip(audio_path)

    # adding audio to the video clip
    videoclip = clip.set_audio(audioclip)

    # saving the final processed video with music
    videoclip.write_videofile(combined_video_path)
    # Print finish status and the processing time
    print("Your combined video with music is saved at: {}".format(combined_video_path))

    return videoclip

def main(url_path):
    """
    Get a youtube video url, this function make person detection on each frame, then generate the processed video.
    Different person has different bounding box color. The audio is combined with the processed video at the end
    of the pileline
    :param url_path: Youtube video url
    :return: processed video with object detection, combined with its original audio
    """
    # ------------- Create Directory & Path - -------------  #
    # Create download directory for video
    create_dir(VIDEO_IN_PATH)

    # Create directory for extracted audio
    create_dir(AUDIO_PATH)

    # Create output video directory to save processed video
    create_dir(VIDEO_OUT_PATH)

    # Get audio path
    audio_path = os.path.join(AUDIO_PATH, AUDIO_NAME + AUDIO_EXT)

    # Get path of video output without music
    output_video_no_ext = os.path.join(VIDEO_OUT_PATH, OUT_VIDEO_NAME)
    output_video_path = os.path.join(VIDEO_OUT_PATH, OUT_VIDEO_NAME + OUT_VIDEO_EXT)

    # Create path of the final processed video with its original music
    combined_output_video = os.path.join(VIDEO_OUT_PATH, OUT_VIDEO_MUSIC_NAME + OUT_VIDEO_EXT)

    # ------------- Download Video, Extract Audio, Object Detection & Render --------------#

    # Download youtube video and get video path
    video_path = download_youtube_video(url_path, VIDEO_IN_PATH)

    # Extract audio from video and show audio path
    extract_audio_from_video(video_path, audio_path)

    # Run the model prediction for video object detection
    render_video_detection(video_path, output_video_no_ext, detector, custom_objects, COLORS, ext=OUT_VIDEO_EXT)

    # Start render final video with music and saving
    _ = render_video_music(output_video_path, audio_path, combined_output_video)

# %% [markdown]
# # Run pipeline

# %%
main(VIDEO_URL)
# Out:
# Video file is saved at: video_in/MISS DIOR – The new Eau de Parfum.mp4
# chunk:  17%|█▋        | 167/993 [00:00<00:00, 1667.36it/s, now=None]
# MoviePy - Writing audio in audio/dior_audio.mp3
# MoviePy - Done.
# Audio file is saved at: audio/dior_audio.mp3
# Frame: 1 is processed.
# ----------------------
# Frame: 2 is processed.
# ----------------------
# Frame: 3 is processed.
# ----------------------
# Frame: 4 is processed.
# ----------------------
# Frame: 5 is processed.
# ----------------------
# Frame: 6 is processed.
# ----------------------
# Frame: 7 is processed.
# ----------------------
# Frame: 8 is processed.
# ----------------------
# Frame: 9 is processed.
# ----------------------
# Frame: 10 is processed.
# ----------------------
# Frame: 11 is processed.
# ----------------------
# Frame: 12 is processed.
# ----------------------
# Frame: 13 is processed.
# ----------------------
# Frame: 14 is processed.
# ----------------------
# Frame: 15 is processed.
# ----------------------
# Frame: 16 is processed.
# ----------------------
# Frame: 17 is processed.
# ----------------------
# Frame: 18 is processed.
# ----------------------
# Frame: 19 is processed.
# ----------------------
# Frame: 20 is processed.
# ----------------------
# Frame: 21 is processed.
# ----------------------
# Frame: 22 is processed.
# ----------------------
# Frame: 23 is processed.
# ----------------------
# Frame: 24 is processed.
# ----------------------
# Frame: 25 is processed.
# ----------------------
# Frame: 26 is processed.
# ----------------------
# Frame: 27 is processed.
# ----------------------
# Frame: 28 is processed.
# ----------------------
# Frame: 29 is processed.
# ----------------------
# Frame: 30 is processed.
# ----------------------
# Frame: 31 is processed.
# ----------------------
# Frame: 32 is processed.
# ----------------------
# Frame: 33 is processed.
# ----------------------
# Frame: 34 is processed.
# ----------------------
# Frame: 35 is processed.
# ----------------------
# Frame: 36 is processed.
# ----------------------
# Frame: 37 is processed.
# ----------------------
# Frame: 38 is processed.
# ----------------------
# Frame: 39 is processed.
# ----------------------
# Frame: 40 is processed.
# ----------------------
# Frame: 41 is processed.
# ----------------------
# Frame: 42 is processed.
# ----------------------
# Frame: 43 is processed.
# ----------------------
# Frame: 44 is processed.
# ----------------------
# Frame: 45 is processed.
# ----------------------
# Frame: 46 is processed.
# ----------------------
# Frame: 47 is processed.
# ----------------------
# Frame: 48 is processed.
# ----------------------
# Frame: 49 is processed.
# ----------------------
# Frame: 50 is processed.
# ----------------------
# Frame: 51 is processed.
# ----------------------
# Frame: 52 is processed.
# ----------------------
# Frame: 53 is processed.
# ----------------------
# Frame: 54 is processed.
# ----------------------
# Frame: 55 is processed.
# ----------------------
# Frame: 56 is processed.
# ----------------------
# Frame: 57 is processed.
# ----------------------
# Frame: 58 is processed.
# ----------------------
# Frame: 59 is processed.
# ----------------------
# Frame: 60 is processed.
# ----------------------
# Frame: 61 is processed.
# ----------------------
# Frame: 62 is processed.
# ----------------------
# Frame: 63 is processed.
# ----------------------
# Frame: 64 is processed.
# ----------------------
# Frame: 65 is processed.
# ----------------------
# Frame: 66 is processed.
# ----------------------
# Frame: 67 is processed.
# ----------------------
# Frame: 68 is processed.
# ----------------------
# Frame: 69 is processed.
# ----------------------
# Frame: 70 is processed.
# ----------------------
# Frame: 71 is processed.
# ----------------------
# Frame: 72 is processed.
# ----------------------
# Frame: 73 is processed.
# ----------------------
# Frame: 74 is processed.
# ----------------------
# Frame: 75 is processed.
# ----------------------
# Frame: 76 is processed.
# ----------------------
# Frame: 77 is processed.
# ----------------------
# Frame: 78 is processed.
# ----------------------
# Frame: 79 is processed.
# ----------------------
# Frame: 80 is processed.
# ----------------------
# Frame: 81 is processed.
# ----------------------
# Frame: 82 is processed.
# ----------------------
# Frame: 83 is processed.
# ----------------------
# Frame: 84 is processed.
# ----------------------
# Frame: 85 is processed.
# ----------------------
# Frame: 86 is processed.
# ----------------------
# Frame: 87 is processed.
# ----------------------
# Frame: 88 is processed.
# ----------------------
# Frame: 89 is processed.
# ----------------------
# Frame: 90 is processed.
# ----------------------
# Frame: 91 is processed.
# ----------------------
# Frame: 92 is processed.
# ----------------------
# Frame: 93 is processed.
# ----------------------
# Frame: 94 is processed.
# ----------------------
# Frame: 95 is processed.
# ----------------------
# Frame: 96 is processed.
# ----------------------
# Frame: 97 is processed.
# ----------------------
# Frame: 98 is processed.
# ----------------------
# Frame: 99 is processed.
# ----------------------
# Frame: 100 is processed.
# ----------------------
# Frame: 101 is processed.
# ----------------------
# Frame: 102 is processed.
# ----------------------
# Frame: 103 is processed.
# ----------------------
# Frame: 104 is processed.
# ----------------------
# Frame: 105 is processed.
# ----------------------
# Frame: 106 is processed.
# ----------------------
# Frame: 107 is processed.
# ----------------------
# Frame: 108 is processed.
# ----------------------
# Frame: 109 is processed.
# ----------------------
# Frame: 110 is processed.
# ----------------------
# Frame: 111 is processed.
# ----------------------
# Frame: 112 is processed.
# ----------------------
# Frame: 113 is processed.
# ----------------------
# Frame: 114 is processed.
# ----------------------
# Frame: 115 is processed.
# ----------------------
# Frame: 116 is processed.
# ----------------------
# Frame: 117 is processed.
# ----------------------
# Frame: 118 is processed.
# ----------------------
# Frame: 119 is processed.
# ----------------------
# Frame: 120 is processed.
# ----------------------
# Frame: 121 is processed.
# ----------------------
# Frame: 122 is processed.
# ----------------------
# Frame: 123 is processed.
# ----------------------
# Frame: 124 is processed.
# ----------------------
# Frame: 125 is processed.
# ----------------------
# Frame: 126 is processed.
# ----------------------
# Frame: 127 is processed.
# ----------------------
# Frame: 128 is processed.
# ----------------------
# Frame: 129 is processed.
# ----------------------
# Frame: 130 is processed.
# ----------------------
# Frame: 131 is processed.
# ----------------------
# Frame: 132 is processed.
# ----------------------
# Frame: 133 is processed.
# ----------------------
# Frame: 134 is processed.
# ----------------------
# Frame: 135 is processed.
# ----------------------
# Frame: 136 is processed.
# ----------------------
# Frame: 137 is processed.
# ----------------------
# Frame: 138 is processed.
# ----------------------
# Frame: 139 is processed.
# ----------------------
# Frame: 140 is processed.
# ----------------------
# Frame: 141 is processed.
# ----------------------
# Frame: 142 is processed.
# ----------------------
# Frame: 143 is processed.
# ----------------------
# Frame: 144 is processed.
# ----------------------
# Frame: 145 is processed.
# ----------------------
# Frame: 146 is processed.
# ----------------------
# Frame: 147 is processed.
# ----------------------
# Frame: 148 is processed.
# ----------------------
# Frame: 149 is processed.
# ----------------------
# Frame: 150 is processed.
# ----------------------
# Frame: 151 is processed.
# ----------------------
# Frame: 152 is processed.
# ----------------------
# Frame: 153 is processed.
# ----------------------
# Frame: 154 is processed.
# ----------------------
# Frame: 155 is processed.
# ----------------------
# Frame: 156 is processed.
# ----------------------
# Frame: 157 is processed.
# ----------------------
# Frame: 158 is processed.
# ----------------------
# Frame: 159 is processed.
# ----------------------
# Frame: 160 is processed.
# ----------------------
# Frame: 161 is processed.
# ----------------------
# Frame: 162 is processed.
# ----------------------
# Frame: 163 is processed.
# ----------------------
# Frame: 164 is processed.
# ----------------------
# Frame: 165 is processed.
# ----------------------
# Frame: 166 is processed.
# ----------------------
# Frame: 167 is processed.
# ----------------------
# Frame: 168 is processed.
# ----------------------
# Frame: 169 is processed.
# ----------------------
# Frame: 170 is processed.
# ----------------------
# Frame: 171 is processed.
# ----------------------
# Frame: 172 is processed.
# ----------------------
# Frame: 173 is processed.
# ----------------------
# Frame: 174 is processed.
# ----------------------
# Frame: 175 is processed.
# ----------------------
# Frame: 176 is processed.
# ----------------------
# Frame: 177 is processed.
# ----------------------
# Frame: 178 is processed.
# ----------------------
# Frame: 179 is processed.
# ----------------------
# Frame: 180 is processed.
# ----------------------
# Frame: 181 is processed.
# ----------------------
# Frame: 182 is processed.
# ----------------------
# Frame: 183 is processed.
# ----------------------
# Frame: 184 is processed.
# ----------------------
# Frame: 185 is processed.
# ----------------------
# Frame: 186 is processed.
# ----------------------
# Frame: 187 is processed.
# ----------------------
# Frame: 188 is processed.
# ----------------------
# Frame: 189 is processed.
# ----------------------
# Frame: 190 is processed.
# ----------------------
# Frame: 191 is processed.
# ----------------------
# Frame: 192 is processed.
# ----------------------
# Frame: 193 is processed.
# ----------------------
# Frame: 194 is processed.
# ----------------------
# Frame: 195 is processed.
# ----------------------
# Frame: 196 is processed.
# ----------------------
# Frame: 197 is processed.
# ----------------------
# Frame: 198 is processed.
# ----------------------
# Frame: 199 is processed.
# ----------------------
# Frame: 200 is processed.
# ----------------------
# Frame: 201 is processed.
# ----------------------
# Frame: 202 is processed.
# ----------------------
# Frame: 203 is processed.
# ----------------------
# Frame: 204 is processed.
# ----------------------
# Frame: 205 is processed.
# ----------------------
# Frame: 206 is processed.
# ----------------------
# Frame: 207 is processed.
# ----------------------
# Frame: 208 is processed.
# ----------------------
# Frame: 209 is processed.
# ----------------------
# Frame: 210 is processed.
# ----------------------
# Frame: 211 is processed.
# ----------------------
# Frame: 212 is processed.
# ----------------------
# Frame: 213 is processed.
# ----------------------
# Frame: 214 is processed.
# ----------------------
# Frame: 215 is processed.
# ----------------------
# Frame: 216 is processed.
# ----------------------
# Frame: 217 is processed.
# ----------------------
# Frame: 218 is processed.
# ----------------------
# Frame: 219 is processed.
# ----------------------
# Frame: 220 is processed.
# ----------------------
# Frame: 221 is processed.
# ----------------------
# Frame: 222 is processed.
# ----------------------
# Frame: 223 is processed.
# ----------------------
# Frame: 224 is processed.
# ----------------------
# Frame: 225 is processed.
# ----------------------
# Frame: 226 is processed.
# ----------------------
# Frame: 227 is processed.
# ----------------------
# Frame: 228 is processed.
# ----------------------
# Frame: 229 is processed.
# ----------------------
# Frame: 230 is processed.
# ----------------------
# Frame: 231 is processed.
# ----------------------
# Frame: 232 is processed.
# ----------------------
# Frame: 233 is processed.
# ----------------------
# Frame: 234 is processed.
# ----------------------
# Frame: 235 is processed.
# ----------------------
# Frame: 236 is processed.
# ----------------------
# Frame: 237 is processed.
# ----------------------
# Frame: 238 is processed.
# ----------------------
# Frame: 239 is processed.
# ----------------------
# Frame: 240 is processed.
# ----------------------
# Frame: 241 is processed.
# ----------------------
# Frame: 242 is processed.
# ----------------------
# Frame: 243 is processed.
# ----------------------
# Frame: 244 is processed.
# ----------------------
# Frame: 245 is processed.
# ----------------------
# Frame: 246 is processed.
# ----------------------
# Frame: 247 is processed.
# ----------------------
# Frame: 248 is processed.
# ----------------------
# Frame: 249 is processed.
# ----------------------
# Frame: 250 is processed.
# ----------------------
# Frame: 251 is processed.
# ----------------------
# Frame: 252 is processed.
# ----------------------
# Frame: 253 is processed.
# ----------------------
# Frame: 254 is processed.
# ----------------------
# Frame: 255 is processed.
# ----------------------
# Frame: 256 is processed.
# ----------------------
# Frame: 257 is processed.
# ----------------------
# Frame: 258 is processed.
# ----------------------
# Frame: 259 is processed.
# ----------------------
# Frame: 260 is processed.
# ----------------------
# Frame: 261 is processed.
# ----------------------
# Frame: 262 is processed.
# ----------------------
# Frame: 263 is processed.
# ----------------------
# Frame: 264 is processed.
# ----------------------
# Frame: 265 is processed.
# ----------------------
# Frame: 266 is processed.
# ----------------------
# Frame: 267 is processed.
# ----------------------
# Frame: 268 is processed.
# ----------------------
# Frame: 269 is processed.
# ----------------------
# Frame: 270 is processed.
# ----------------------
# Frame: 271 is processed.
# ----------------------
# Frame: 272 is processed.
# ----------------------
# Frame: 273 is processed.
# ----------------------
# Frame: 274 is processed.
# ----------------------
# Frame: 275 is processed.
# ----------------------
# Frame: 276 is processed.
# ----------------------
# Frame: 277 is processed.
# ----------------------
# Frame: 278 is processed.
# ----------------------
# Frame: 279 is processed.
# ----------------------
# Frame: 280 is processed.
# ----------------------
# Frame: 281 is processed.
# ----------------------
# Frame: 282 is processed.
# ----------------------
# Frame: 283 is processed.
# ----------------------
# Frame: 284 is processed.
# ----------------------
# Frame: 285 is processed.
# ----------------------
# Frame: 286 is processed.
# ----------------------
# Frame: 287 is processed.
# ----------------------
# Frame: 288 is processed.
# ----------------------
# Frame: 289 is processed.
# ----------------------
# Frame: 290 is processed.
# ----------------------
# Frame: 291 is processed.
# ----------------------
# Frame: 292 is processed.
# ----------------------
# Frame: 293 is processed.
# ----------------------
# Frame: 294 is processed.
# ----------------------
# Frame: 295 is processed.
# ----------------------
# Frame: 296 is processed.
# ----------------------
# Frame: 297 is processed.
# ----------------------
# Frame: 298 is processed.
# ----------------------
# Frame: 299 is processed.
# ----------------------
# Frame: 300 is processed.
# ----------------------
# Frame: 301 is processed.
# ----------------------
# Frame: 302 is processed.
# ----------------------
# Frame: 303 is processed.
# ----------------------
# Frame: 304 is processed.
# ----------------------
# Frame: 305 is processed.
# ----------------------
# Frame: 306 is processed.
# ----------------------
# Frame: 307 is processed.
# ----------------------
# Frame: 308 is processed.
# ----------------------
# Frame: 309 is processed.
# ----------------------
# Frame: 310 is processed.
# ----------------------
# Frame: 311 is processed.
# ----------------------
# Frame: 312 is processed.
# ----------------------
# Frame: 313 is processed.
# ----------------------
# Frame: 314 is processed.
# ----------------------
# Frame: 315 is processed.
# ----------------------
# Frame: 316 is processed.
# ----------------------
# Frame: 317 is processed.
# ----------------------
# Frame: 318 is processed.
# ----------------------
# Frame: 319 is processed.
# ----------------------
# Frame: 320 is processed.
# ----------------------
# Frame: 321 is processed.
# ----------------------
# Frame: 322 is processed.
# ----------------------
# Frame: 323 is processed.
# ----------------------
# Frame: 324 is processed.
# ----------------------
# Frame: 325 is processed.
# ----------------------
# Frame: 326 is processed.
# ----------------------
# Frame: 327 is processed.
# ----------------------
# Frame: 328 is processed.
# ----------------------
# Frame: 329 is processed.
# ----------------------
# Frame: 330 is processed.
# ----------------------
# Frame: 331 is processed.
# ----------------------
# Frame: 332 is processed.
# ----------------------
# Frame: 333 is processed.
# ----------------------
# Frame: 334 is processed.
# ----------------------
# Frame: 335 is processed.
# ----------------------
# Frame: 336 is processed.
# ----------------------
# Frame: 337 is processed.
# ----------------------
# Frame: 338 is processed.
# ----------------------
# Frame: 339 is processed.
# ----------------------
# Frame: 340 is processed.
# ----------------------
# Frame: 341 is processed.
# ----------------------
# Frame: 342 is processed.
# ----------------------
# Frame: 343 is processed.
# ----------------------
# Frame: 344 is processed.
# ----------------------
# Frame: 345 is processed.
# ----------------------
# Frame: 346 is processed.
# ----------------------
# Frame: 347 is processed.
# ----------------------
# Frame: 348 is processed.
# ----------------------
# Frame: 349 is processed.
# ----------------------
# Frame: 350 is processed.
# ----------------------
# Frame: 351 is processed.
# ----------------------
# Frame: 352 is processed.
# ----------------------
# Frame: 353 is processed.
# ----------------------
# Frame: 354 is processed.
# ----------------------
# Frame: 355 is processed.
# ----------------------
# Frame: 356 is processed.
# ----------------------
# Frame: 357 is processed.
# ----------------------
# Frame: 358 is processed.
# ----------------------
# Frame: 359 is processed.
# ----------------------
# Frame: 360 is processed.
# ----------------------
# Frame: 361 is processed.
# ----------------------
# Frame: 362 is processed.
# ----------------------
# Frame: 363 is processed.
# ----------------------
# Frame: 364 is processed.
# ----------------------
# Frame: 365 is processed.
# ----------------------
# Frame: 366 is processed.
# ----------------------
# Frame: 367 is processed.
# ----------------------
# Frame: 368 is processed.
# ----------------------
# Frame: 369 is processed.
# ----------------------
# Frame: 370 is processed.
# ----------------------
# Frame: 371 is processed.
# ----------------------
# Frame: 372 is processed.
# ----------------------
# Frame: 373 is processed.
# ----------------------
# Frame: 374 is processed.
# ----------------------
# Frame: 375 is processed.
# ----------------------
# Frame: 376 is processed.
# ----------------------
# Frame: 377 is processed.
# ----------------------
# Frame: 378 is processed.
# ----------------------
# Frame: 379 is processed.
# ----------------------
# Frame: 380 is processed.
# ----------------------
# Frame: 381 is processed.
# ----------------------
# Frame: 382 is processed.
# ----------------------
# Frame: 383 is processed.
# ----------------------
# Frame: 384 is processed.
# ----------------------
# Frame: 385 is processed.
# ----------------------
# Frame: 386 is processed.
# ----------------------
# Frame: 387 is processed.
# ----------------------
# Frame: 388 is processed.
# ----------------------
# Frame: 389 is processed.
# ----------------------
# Frame: 390 is processed.
# ----------------------
# Frame: 391 is processed.
# ----------------------
# Frame: 392 is processed.
# ----------------------
# Frame: 393 is processed.
# ----------------------
# Frame: 394 is processed.
# ----------------------
# Frame: 395 is processed.
# ----------------------
# Frame: 396 is processed.
# ----------------------
# Frame: 397 is processed.
# ----------------------
# Frame: 398 is processed.
# ----------------------
# Frame: 399 is processed.
# ----------------------
# Frame: 400 is processed.
# ----------------------
# Frame: 401 is processed.
# ----------------------
# Frame: 402 is processed.
# ----------------------
# Frame: 403 is processed.
# ----------------------
# Frame: 404 is processed.
# ----------------------
# Frame: 405 is processed.
# ----------------------
# Frame: 406 is processed.
# ----------------------
# Frame: 407 is processed.
# ----------------------
# Frame: 408 is processed.
# ----------------------
# Frame: 409 is processed.
# ----------------------
# Frame: 410 is processed.
# ----------------------
# Frame: 411 is processed.
# ----------------------
# Frame: 412 is processed.
# ----------------------
# Frame: 413 is processed.
# ----------------------
# Frame: 414 is processed.
# ----------------------
# Frame: 415 is processed.
# ----------------------
# Frame: 416 is processed.
# ----------------------
# Frame: 417 is processed.
# ----------------------
# Frame: 418 is processed.
# ----------------------
# Frame: 419 is processed.
# ----------------------
# Frame: 420 is processed.
# ----------------------
# Frame: 421 is processed.
# ----------------------
# Frame: 422 is processed.
# ----------------------
# Frame: 423 is processed.
# ----------------------
# Frame: 424 is processed.
# ----------------------
# Frame: 425 is processed.
# ----------------------
# Frame: 426 is processed.
# ----------------------
# Frame: 427 is processed.
# ----------------------
# Frame: 428 is processed.
# ----------------------
# Frame: 429 is processed.
# ----------------------
# Frame: 430 is processed.
# ----------------------
# Frame: 431 is processed.
# ----------------------
# Frame: 432 is processed.
# ----------------------
# Frame: 433 is processed.
# ----------------------
# Frame: 434 is processed.
# ----------------------
# Frame: 435 is processed.
# ----------------------
# Frame: 436 is processed.
# ----------------------
# Frame: 437 is processed.
# ----------------------
# Frame: 438 is processed.
# ----------------------
# Frame: 439 is processed.
# ----------------------
# Frame: 440 is processed.
# ----------------------
# Frame: 441 is processed.
# ----------------------
# Frame: 442 is processed.
# ----------------------
# Frame: 443 is processed.
# ----------------------
# Frame: 444 is processed.
# ----------------------
# Frame: 445 is processed.
# ----------------------
# Frame: 446 is processed.
# ----------------------
# Frame: 447 is processed.
# ----------------------
# Frame: 448 is processed.
# ----------------------
# Frame: 449 is processed.
# ----------------------
# Frame: 450 is processed.
# ----------------------
# Frame: 451 is processed.
# ----------------------
# Frame: 452 is processed.
# ----------------------
# Frame: 453 is processed.
# ----------------------
# Frame: 454 is processed.
# ----------------------
# Frame: 455 is processed.
# ----------------------
# Frame: 456 is processed.
# ----------------------
# Frame: 457 is processed.
# ----------------------
# Frame: 458 is processed.
# ----------------------
# Frame: 459 is processed.
# ----------------------
# Frame: 460 is processed.
# ----------------------
# Frame: 461 is processed.
# ----------------------
# Frame: 462 is processed.
# ----------------------
# Frame: 463 is processed.
# ----------------------
# Frame: 464 is processed.
# ----------------------
# Frame: 465 is processed.
# ----------------------
# Frame: 466 is processed.
# ----------------------
# Frame: 467 is processed.
# ----------------------
# Frame: 468 is processed.
# ----------------------
# Frame: 469 is processed.
# ----------------------
# Frame: 470 is processed.
# ----------------------
# Frame: 471 is processed.
# ----------------------
# Frame: 472 is processed.
# ----------------------
# Frame: 473 is processed.
# ----------------------
# Frame: 474 is processed.
# ----------------------
# Frame: 475 is processed.
# ----------------------
# Frame: 476 is processed.
# ----------------------
# Frame: 477 is processed.
# ----------------------
# Frame: 478 is processed.
# ----------------------
# Frame: 479 is processed.
# ----------------------
# Frame: 480 is processed.
# ----------------------
# Frame: 481 is processed.
# ----------------------
# Frame: 482 is processed.
# ----------------------
# Frame: 483 is processed.
# ----------------------
# Frame: 484 is processed.
# ----------------------
# Frame: 485 is processed.
# ----------------------
# Frame: 486 is processed.
# ----------------------
# Frame: 487 is processed.
# ----------------------
# Frame: 488 is processed.
# ----------------------
# Frame: 489 is processed.
# ----------------------
# Frame: 490 is processed.
# ----------------------
# Frame: 491 is processed.
# ----------------------
# Frame: 492 is processed.
# ----------------------
# Frame: 493 is processed.
# ----------------------
# Frame: 494 is processed.
# ----------------------
# Frame: 495 is processed.
# ----------------------
# Frame: 496 is processed.
# ----------------------
# Frame: 497 is processed.
# ----------------------
# Frame: 498 is processed.
# ----------------------
# Frame: 499 is processed.
# ----------------------
# Frame: 500 is processed.
# ----------------------
# Frame: 501 is processed.
# ----------------------
# Frame: 502 is processed.
# ----------------------
# Frame: 503 is processed.
# ----------------------
# Frame: 504 is processed.
# ----------------------
# Frame: 505 is processed.
# ----------------------
# Frame: 506 is processed.
# ----------------------
# Frame: 507 is processed.
# ----------------------
# Frame: 508 is processed.
# ----------------------
# Frame: 509 is processed.
# ----------------------
# Frame: 510 is processed.
# ----------------------
# Frame: 511 is processed.
# ----------------------
# Frame: 512 is processed.
# ----------------------
# Frame: 513 is processed.
# ----------------------
# Frame: 514 is processed.
# ----------------------
# Frame: 515 is processed.
# ----------------------
# Frame: 516 is processed.
# ----------------------
# Frame: 517 is processed.
# ----------------------
# Frame: 518 is processed.
# ----------------------
# Frame: 519 is processed.
# ----------------------
# Frame: 520 is processed.
# ----------------------
# Frame: 521 is processed.
# ----------------------
# Frame: 522 is processed.
# ----------------------
# Frame: 523 is processed.
# ----------------------
# Frame: 524 is processed.
# ----------------------
# Frame: 525 is processed.
# ----------------------
# Frame: 526 is processed.
# ----------------------
# Frame: 527 is processed.
# ----------------------
# Frame: 528 is processed.
# ----------------------
# Frame: 529 is processed.
# ----------------------
# Frame: 530 is processed.
# ----------------------
# Frame: 531 is processed.
# ----------------------
# Frame: 532 is processed.
# ----------------------
# Frame: 533 is processed.
# ----------------------
# Frame: 534 is processed.
# ----------------------
# Frame: 535 is processed.
# ----------------------
# Frame: 536 is processed.
# ----------------------
# Frame: 537 is processed.
# ----------------------
# Frame: 538 is processed.
# ----------------------
# Frame: 539 is processed.
# ----------------------
# Frame: 540 is processed.
# ----------------------
# Frame: 541 is processed.
# ----------------------
# Frame: 542 is processed.
# ----------------------
# Frame: 543 is processed.
# ----------------------
# Frame: 544 is processed.
# ----------------------
# Frame: 545 is processed.
# ----------------------
# Frame: 546 is processed.
# ----------------------
# Frame: 547 is processed.
# ----------------------
# Frame: 548 is processed.
# ----------------------
# Frame: 549 is processed.
# ----------------------
# Frame: 550 is processed.
# ----------------------
# Frame: 551 is processed.
# ----------------------
# Frame: 552 is processed.
# ----------------------
# Frame: 553 is processed.
# ----------------------
# Frame: 554 is processed.
# ----------------------
# Frame: 555 is processed.
# ----------------------
# Frame: 556 is processed.
# ----------------------
# Frame: 557 is processed.
# ----------------------
# Frame: 558 is processed.
# ----------------------
# Frame: 559 is processed.
# ----------------------
# Frame: 560 is processed.
# ----------------------
# Frame: 561 is processed.
# ----------------------
# Frame: 562 is processed.
# ----------------------
# Frame: 563 is processed.
# ----------------------
# Frame: 564 is processed.
# ----------------------
# Frame: 565 is processed.
# ----------------------
# Frame: 566 is processed.
# ----------------------
# Frame: 567 is processed.
# ----------------------
# Frame: 568 is processed.
# ----------------------
# Frame: 569 is processed.
# ----------------------
# Frame: 570 is processed.
# ----------------------
# Frame: 571 is processed.
# ----------------------
# Frame: 572 is processed.
# ----------------------
# Frame: 573 is processed.
# ----------------------
# Frame: 574 is processed.
# ----------------------
# Frame: 575 is processed.
# ----------------------
# Frame: 576 is processed.
# ----------------------
# Frame: 577 is processed.
# ----------------------
# Frame: 578 is processed.
# ----------------------
# Frame: 579 is processed.
# ----------------------
# Frame: 580 is processed.
# ----------------------
# Frame: 581 is processed.
# ----------------------
# Frame: 582 is processed.
# ----------------------
# Frame: 583 is processed.
# ----------------------
# Frame: 584 is processed.
# ----------------------
# Frame: 585 is processed.
# ----------------------
# Frame: 586 is processed.
# ----------------------
# Frame: 587 is processed.
# ----------------------
# Frame: 588 is processed.
# ----------------------
# Frame: 589 is processed.
# ----------------------
# Frame: 590 is processed.
# ----------------------
# Frame: 591 is processed.
# ----------------------
# Frame: 592 is processed.
# ----------------------
# Frame: 593 is processed.
# ----------------------
# Frame: 594 is processed.
# ----------------------
# Frame: 595 is processed.
# ----------------------
# Frame: 596 is processed.
# ----------------------
# Frame: 597 is processed.
# ----------------------
# Frame: 598 is processed.
# ----------------------
# Frame: 599 is processed.
# ----------------------
# Frame: 600 is processed.
# ----------------------
# Frame: 601 is processed.
# ----------------------
# Frame: 602 is processed.
# ----------------------
# Frame: 603 is processed.
# ----------------------
# Frame: 604 is processed.
# ----------------------
# Frame: 605 is processed.
# ----------------------
# Frame: 606 is processed.
# ----------------------
# Frame: 607 is processed.
# ----------------------
# Frame: 608 is processed.
# ----------------------
# Frame: 609 is processed.
# ----------------------
# Frame: 610 is processed.
# ----------------------
# Frame: 611 is processed.
# ----------------------
# Frame: 612 is processed.
# ----------------------
# Frame: 613 is processed.
# ----------------------
# Frame: 614 is processed.
# ----------------------
# Frame: 615 is processed.
# ----------------------
# Frame: 616 is processed.
# ----------------------
# Frame: 617 is processed.
# ----------------------
# Frame: 618 is processed.
# ----------------------
# Frame: 619 is processed.
# ----------------------
# Frame: 620 is processed.
# ----------------------
# Frame: 621 is processed.
# ----------------------
# Frame: 622 is processed.
# ----------------------
# Frame: 623 is processed.
# ----------------------
# Frame: 624 is processed.
# ----------------------
# Frame: 625 is processed.
# ----------------------
# Frame: 626 is processed.
# ----------------------
# Frame: 627 is processed.
# ----------------------
# Frame: 628 is processed.
# ----------------------
# Frame: 629 is processed.
# ----------------------
# Frame: 630 is processed.
# ----------------------
# Frame: 631 is processed.
# ----------------------
# Frame: 632 is processed.
# ----------------------
# Frame: 633 is processed.
# ----------------------
# Frame: 634 is processed.
# ----------------------
# Frame: 635 is processed.
# ----------------------
# Frame: 636 is processed.
# ----------------------
# Frame: 637 is processed.
# ----------------------
# Frame: 638 is processed.
# ----------------------
# Frame: 639 is processed.
# ----------------------
# Frame: 640 is processed.
# ----------------------
# Frame: 641 is processed.
# ----------------------
# Frame: 642 is processed.
# ----------------------
# Frame: 643 is processed.
# ----------------------
# Frame: 644 is processed.
# ----------------------
# Frame: 645 is processed.
# ----------------------
# Frame: 646 is processed.
# ----------------------
# Frame: 647 is processed.
# ----------------------
# Frame: 648 is processed.
# ----------------------
# Frame: 649 is processed.
# ----------------------
# Frame: 650 is processed.
# ----------------------
# Frame: 651 is processed.
# ----------------------
# Frame: 652 is processed.
# ----------------------
# Frame: 653 is processed.
# ----------------------
# Frame: 654 is processed.
# ----------------------
# Frame: 655 is processed.
# ----------------------
# Frame: 656 is processed.
# ----------------------
# Frame: 657 is processed.
# ----------------------
# Frame: 658 is processed.
# ----------------------
# Frame: 659 is processed.
# ----------------------
# Frame: 660 is processed.
# ----------------------
# Frame: 661 is processed.
# ----------------------
# Frame: 662 is processed.
# ----------------------
# Frame: 663 is processed.
# ----------------------
# Frame: 664 is processed.
# ----------------------
# Frame: 665 is processed.
# ----------------------
# Frame: 666 is processed.
# ----------------------
# Frame: 667 is processed.
# ----------------------
# Frame: 668 is processed.
# ----------------------
# Frame: 669 is processed.
# ----------------------
# Frame: 670 is processed.
# ----------------------
# Frame: 671 is processed.
# ----------------------
# Frame: 672 is processed.
# ----------------------
# Frame: 673 is processed.
# ----------------------
# Frame: 674 is processed.
# ----------------------
# Frame: 675 is processed.
# ----------------------
# Frame: 676 is processed.
# ----------------------
# Frame: 677 is processed.
# ----------------------
# Frame: 678 is processed.
# ----------------------
# Frame: 679 is processed.
# ----------------------
# Frame: 680 is processed.
# ----------------------
# Frame: 681 is processed.
# ----------------------
# Frame: 682 is processed.
# ----------------------
# Frame: 683 is processed.
# ----------------------
# Frame: 684 is processed.
# ----------------------
# Frame: 685 is processed.
# ----------------------
# Frame: 686 is processed.
# ----------------------
# Frame: 687 is processed.
# ----------------------
# Frame: 688 is processed.
# ----------------------
# Frame: 689 is processed.
# ----------------------
# Frame: 690 is processed.
# ----------------------
# Frame: 691 is processed.
# ----------------------
# Frame: 692 is processed.
# ----------------------
# Frame: 693 is processed.
# ----------------------
# Frame: 694 is processed.
# ----------------------
# Frame: 695 is processed.
# ----------------------
# Frame: 696 is processed.
# ----------------------
# Frame: 697 is processed.
# ----------------------
# Frame: 698 is processed.
# ----------------------
# Frame: 699 is processed.
# ----------------------
# Frame: 700 is processed.
# ----------------------
# Frame: 701 is processed.
# ----------------------
# Frame: 702 is processed.
# ----------------------
# Frame: 703 is processed.
# ----------------------
# Frame: 704 is processed.
# ----------------------
# Frame: 705 is processed.
# ----------------------
# Frame: 706 is processed.
# ----------------------
# Frame: 707 is processed.
# ----------------------
# Frame: 708 is processed.
# ----------------------
# Frame: 709 is processed.
# ----------------------
# Frame: 710 is processed.
# ----------------------
# Frame: 711 is processed.
# ----------------------
# Frame: 712 is processed.
# ----------------------
# Frame: 713 is processed.
# ----------------------
# Frame: 714 is processed.
# ----------------------
# Frame: 715 is processed.
# ----------------------
# Frame: 716 is processed.
# ----------------------
# Frame: 717 is processed.
# ----------------------
# Frame: 718 is processed.
# ----------------------
# Frame: 719 is processed.
# ----------------------
# Frame: 720 is processed.
# ----------------------
# Frame: 721 is processed.
# ----------------------
# Frame: 722 is processed.
# ----------------------
# Frame: 723 is processed.
# ----------------------
# Frame: 724 is processed.
# ----------------------
# Frame: 725 is processed.
# ----------------------
# Frame: 726 is processed.
# ----------------------
# Frame: 727 is processed.
# ----------------------
# Frame: 728 is processed.
# ----------------------
# Frame: 729 is processed.
# ----------------------
# Frame: 730 is processed.
# ----------------------
# Frame: 731 is processed.
# ----------------------
# Frame: 732 is processed.
# ----------------------
# Frame: 733 is processed.
# ----------------------
# Frame: 734 is processed.
# ----------------------
# Frame: 735 is processed.
# ----------------------
# Frame: 736 is processed.
# ----------------------
# Frame: 737 is processed.
# ----------------------
# Frame: 738 is processed.
# ----------------------
# Frame: 739 is processed.
# ----------------------
# Frame: 740 is processed.
# ----------------------
# Frame: 741 is processed.
# ----------------------
# Frame: 742 is processed.
# ----------------------
# Frame: 743 is processed.
# ----------------------
# Frame: 744 is processed.
# ----------------------
# Frame: 745 is processed.
# ----------------------
# Frame: 746 is processed.
# ----------------------
# Frame: 747 is processed.
# ----------------------
# Frame: 748 is processed.
# ----------------------
# Frame: 749 is processed.
# ----------------------
# Frame: 750 is processed.
# ----------------------
# Frame: 751 is processed.
# ----------------------
# Frame: 752 is processed.
# ----------------------
# Frame: 753 is processed.
# ----------------------
# Frame: 754 is processed.
# ----------------------
# Frame: 755 is processed.
# ----------------------
# Frame: 756 is processed.
# ----------------------
# Frame: 757 is processed.
# ----------------------
# Frame: 758 is processed.
# ----------------------
# Frame: 759 is processed.
# ----------------------
# Frame: 760 is processed.
# ----------------------
# Frame: 761 is processed.
# ----------------------
# Frame: 762 is processed.
# ----------------------
# Frame: 763 is processed.
# ----------------------
# Frame: 764 is processed.
# ----------------------
# Frame: 765 is processed.
# ----------------------
# Frame: 766 is processed.
# ----------------------
# Frame: 767 is processed.
# ----------------------
# Frame: 768 is processed.
# ----------------------
# Frame: 769 is processed.
# ----------------------
# Frame: 770 is processed.
# ----------------------
# Frame: 771 is processed.
# ----------------------
# Frame: 772 is processed.
# ----------------------
# Frame: 773 is processed.
# ----------------------
# Frame: 774 is processed.
# ----------------------
# Frame: 775 is processed.
# ----------------------
# Frame: 776 is processed.
# ----------------------
# Frame: 777 is processed.
# ----------------------
# Frame: 778 is processed.
# ----------------------
# Frame: 779 is processed.
# ----------------------
# Frame: 780 is processed.
# ----------------------
# Frame: 781 is processed.
# ----------------------
# Frame: 782 is processed.
# ----------------------
# Frame: 783 is processed.
# ----------------------
# Frame: 784 is processed.
# ----------------------
# Frame: 785 is processed.
# ----------------------
# Frame: 786 is processed.
# ----------------------
# Frame: 787 is processed.
# ----------------------
# Frame: 788 is processed.
# ----------------------
# Frame: 789 is processed.
# ----------------------
# Frame: 790 is processed.
# ----------------------
# Frame: 791 is processed.
# ----------------------
# Frame: 792 is processed.
# ----------------------
# Frame: 793 is processed.
# ----------------------
# Frame: 794 is processed.
# ----------------------
# Frame: 795 is processed.
# ----------------------
# Frame: 796 is processed.
# ----------------------
# Frame: 797 is processed.
# ----------------------
# Frame: 798 is processed.
# ----------------------
# Frame: 799 is processed.
# ----------------------
# Frame: 800 is processed.
# ----------------------
# Frame: 801 is processed.
# ----------------------
# Frame: 802 is processed.
# ----------------------
# Frame: 803 is processed.
# ----------------------
# Frame: 804 is processed.
# ----------------------
# Frame: 805 is processed.
# ----------------------
# Frame: 806 is processed.
# ----------------------
# Frame: 807 is processed.
# ----------------------
# Frame: 808 is processed.
# ----------------------
# Frame: 809 is processed.
# ----------------------
# Frame: 810 is processed.
# ----------------------
# Frame: 811 is processed.
# ----------------------
# Frame: 812 is processed.
# ----------------------
# Frame: 813 is processed.
# ----------------------
# Frame: 814 is processed.
# ----------------------
# Frame: 815 is processed.
# ----------------------
# Frame: 816 is processed.
# ----------------------
# Frame: 817 is processed.
# ----------------------
# Frame: 818 is processed.
# ----------------------
# Frame: 819 is processed.
# ----------------------
# Frame: 820 is processed.
# ----------------------
# Frame: 821 is processed.
# ----------------------
# Frame: 822 is processed.
# ----------------------
# Frame: 823 is processed.
# ----------------------
# Frame: 824 is processed.
# ----------------------
# Frame: 825 is processed.
# ----------------------
# Frame: 826 is processed.
# ----------------------
# Frame: 827 is processed.
# ----------------------
# Frame: 828 is processed.
# ----------------------
# Frame: 829 is processed.
# ----------------------
# Frame: 830 is processed.
# ----------------------
# Frame: 831 is processed.
# ----------------------
# Frame: 832 is processed.
# ----------------------
# Frame: 833 is processed.
# ----------------------
# Frame: 834 is processed.
# ----------------------
# Frame: 835 is processed.
# ----------------------
# Frame: 836 is processed.
# ----------------------
# Frame: 837 is processed.
# ----------------------
# Frame: 838 is processed.
# ----------------------
# Frame: 839 is processed.
# ----------------------
# Frame: 840 is processed.
# ----------------------
# Frame: 841 is processed.
# ----------------------
# Frame: 842 is processed.
# ----------------------
# Frame: 843 is processed.
# ----------------------
# Frame: 844 is processed.
# ----------------------
# Frame: 845 is processed.
# ----------------------
# Frame: 846 is processed.
# ----------------------
# Frame: 847 is processed.
# ----------------------
# Frame: 848 is processed.
# ----------------------
# Frame: 849 is processed.
# ----------------------
# Frame: 850 is processed.
# ----------------------
# Frame: 851 is processed.
# ----------------------
# Frame: 852 is processed.
# ----------------------
# Frame: 853 is processed.
# ----------------------
# Frame: 854 is processed.
# ----------------------
# Frame: 855 is processed.
# ----------------------
# Frame: 856 is processed.
# ----------------------
# Frame: 857 is processed.
# ----------------------
# Frame: 858 is processed.
# ----------------------
# Frame: 859 is processed.
# ----------------------
# Frame: 860 is processed.
# ----------------------
# Frame: 861 is processed.
# ----------------------
# Frame: 862 is processed.
# ----------------------
# Frame: 863 is processed.
# ----------------------
# Frame: 864 is processed.
# ----------------------
# Frame: 865 is processed.
# ----------------------
# Frame: 866 is processed.
# ----------------------
# Frame: 867 is processed.
# ----------------------
# Frame: 868 is processed.
# ----------------------
# Frame: 869 is processed.
# ----------------------
# Frame: 870 is processed.
# ----------------------
# Frame: 871 is processed.
# ----------------------
# Frame: 872 is processed.
# ----------------------
# Frame: 873 is processed.
# ----------------------
# Frame: 874 is processed.
# ----------------------
# Frame: 875 is processed.
# ----------------------
# Frame: 876 is processed.
# ----------------------
# Frame: 877 is processed.
# ----------------------
# Frame: 878 is processed.
# ----------------------
# Frame: 879 is processed.
# ----------------------
# Frame: 880 is processed.
# ----------------------
# Frame: 881 is processed.
# ----------------------
# Frame: 882 is processed.
# ----------------------
# Frame: 883 is processed.
# ----------------------
# Frame: 884 is processed.
# ----------------------
# Frame: 885 is processed.
# ----------------------
# Frame: 886 is processed.
# ----------------------
# Frame: 887 is processed.
# ----------------------
# Frame: 888 is processed.
# ----------------------
# Frame: 889 is processed.
# ----------------------
# Frame: 890 is processed.
# ----------------------
# Frame: 891 is processed.
# ----------------------
# Frame: 892 is processed.
# ----------------------
# Frame: 893 is processed.
# ----------------------
# Frame: 894 is processed.
# ----------------------
# Frame: 895 is processed.
# ----------------------
# Frame: 896 is processed.
# ----------------------
# Frame: 897 is processed.
# ----------------------
# Frame: 898 is processed.
# ----------------------
# Frame: 899 is processed.
# ----------------------
# Frame: 900 is processed.
# ----------------------
# Frame: 901 is processed.
# ----------------------
# Frame: 902 is processed.
# ----------------------
# Frame: 903 is processed.
# ----------------------
# Frame: 904 is processed.
# ----------------------
# Frame: 905 is processed.
# ----------------------
# Frame: 906 is processed.
# ----------------------
# Frame: 907 is processed.
# ----------------------
# Frame: 908 is processed.
# ----------------------
# Frame: 909 is processed.
# ----------------------
# Frame: 910 is processed.
# ----------------------
# Frame: 911 is processed.
# ----------------------
# Frame: 912 is processed.
# ----------------------
# Frame: 913 is processed.
# ----------------------
# Frame: 914 is processed.
# ----------------------
# Frame: 915 is processed.
# ----------------------
# Frame: 916 is processed.
# ----------------------
# Frame: 917 is processed.
# ----------------------
# Frame: 918 is processed.
# ----------------------
# Frame: 919 is processed.
# ----------------------
# Frame: 920 is processed.
# ----------------------
# Frame: 921 is processed.
# ----------------------
# Frame: 922 is processed.
# ----------------------
# Frame: 923 is processed.
# ----------------------
# Frame: 924 is processed.
# ----------------------
# Frame: 925 is processed.
# ----------------------
# Frame: 926 is processed.
# ----------------------
# Frame: 927 is processed.
# ----------------------
# Frame: 928 is processed.
# ----------------------
# Frame: 929 is processed.
# ----------------------
# Frame: 930 is processed.
# ----------------------
# Frame: 931 is processed.
# ----------------------
# Frame: 932 is processed.
# ----------------------
# Frame: 933 is processed.
# ----------------------
# Frame: 934 is processed.
# ----------------------
# Frame: 935 is processed.
# ----------------------
# Frame: 936 is processed.
# ----------------------
# Frame: 937 is processed.
# ----------------------
# Frame: 938 is processed.
# ----------------------
# Frame: 939 is processed.
# ----------------------
# Frame: 940 is processed.
# ----------------------
# Frame: 941 is processed.
# ----------------------
# Frame: 942 is processed.
# ----------------------
# Frame: 943 is processed.
# ----------------------
# Frame: 944 is processed.
# ----------------------
# Frame: 945 is processed.
# ----------------------
# Frame: 946 is processed.
# ----------------------
# Frame: 947 is processed.
# ----------------------
# Frame: 948 is processed.
# ----------------------
# Frame: 949 is processed.
# ----------------------
# Frame: 950 is processed.
# ----------------------
# Frame: 951 is processed.
# ----------------------
# Frame: 952 is processed.
# ----------------------
# Frame: 953 is processed.
# ----------------------
# Frame: 954 is processed.
# ----------------------
# Frame: 955 is processed.
# ----------------------
# Frame: 956 is processed.
# ----------------------
# Frame: 957 is processed.
# ----------------------
# Frame: 958 is processed.
# ----------------------
# Frame: 959 is processed.
# ----------------------
# Frame: 960 is processed.
# ----------------------
# Frame: 961 is processed.
# ----------------------
# Frame: 962 is processed.
# ----------------------
# Frame: 963 is processed.
# ----------------------
# Frame: 964 is processed.
# ----------------------
# Frame: 965 is processed.
# ----------------------
# Frame: 966 is processed.
# ----------------------
# Frame: 967 is processed.
# ----------------------
# Frame: 968 is processed.
# ----------------------
# Frame: 969 is processed.
# ----------------------
# Frame: 970 is processed.
# ----------------------
# Frame: 971 is processed.
# ----------------------
# Frame: 972 is processed.
# ----------------------
# Frame: 973 is processed.
# ----------------------
# Frame: 974 is processed.
# ----------------------
# Frame: 975 is processed.
# ----------------------
# Frame: 976 is processed.
# ----------------------
# Frame: 977 is processed.
# ----------------------
# Frame: 978 is processed.
# ----------------------
# Frame: 979 is processed.
# ----------------------
# Frame: 980 is processed.
# ----------------------
# Frame: 981 is processed.
# ----------------------
# Frame: 982 is processed.
# ----------------------
# Frame: 983 is processed.
# ----------------------
# Frame: 984 is processed.
# ----------------------
# Frame: 985 is processed.
# ----------------------
# Frame: 986 is processed.
# ----------------------
# Frame: 987 is processed.
# ----------------------
# Frame: 988 is processed.
# ----------------------
# Frame: 989 is processed.
# ----------------------
# Frame: 990 is processed.
# ----------------------
# Frame: 991 is processed.
# ----------------------
# Frame: 992 is processed.
# ----------------------
# Frame: 993 is processed.
# ----------------------
# Frame: 994 is processed.
# ----------------------
# Frame: 995 is processed.
# ----------------------
# Frame: 996 is processed.
# ----------------------
# Frame: 997 is processed.
# ----------------------
# Frame: 998 is processed.
# ----------------------
# Frame: 999 is processed.
# ----------------------
# Frame: 1000 is processed.
# ----------------------
# Frame: 1001 is processed.
# ----------------------
# Frame: 1002 is processed.
# ----------------------
# Frame: 1003 is processed.
# ----------------------
# Frame: 1004 is processed.
# ----------------------
# Frame: 1005 is processed.
# ----------------------
# Frame: 1006 is processed.
# ----------------------
# Frame: 1007 is processed.
# ----------------------
# Frame: 1008 is processed.
# ----------------------
# Frame: 1009 is processed.
# ----------------------
# Frame: 1010 is processed.
# ----------------------
# Frame: 1011 is processed.
# ----------------------
# Frame: 1012 is processed.
# ----------------------
# Frame: 1013 is processed.
# ----------------------
# Frame: 1014 is processed.
# ----------------------
# Frame: 1015 is processed.
# ----------------------
# Frame: 1016 is processed.
# ----------------------
# Frame: 1017 is processed.
# ----------------------
# Frame: 1018 is processed.
# ----------------------
# Frame: 1019 is processed.
# ----------------------
# Frame: 1020 is processed.
# ----------------------
# Frame: 1021 is processed.
# ----------------------
# Frame: 1022 is processed.
# ----------------------
# Frame: 1023 is processed.
# ----------------------
# Frame: 1024 is processed.
# ----------------------
# Frame: 1025 is processed.
# ----------------------
# Frame: 1026 is processed.
# ----------------------
# Frame: 1027 is processed.
# ----------------------
# Frame: 1028 is processed.
# ----------------------
# Frame: 1029 is processed.
# ----------------------
# Frame: 1030 is processed.
# ----------------------
# Frame: 1031 is processed.
# ----------------------
# Frame: 1032 is processed.
# ----------------------
# Frame: 1033 is processed.
# ----------------------
# Frame: 1034 is processed.
# ----------------------
# Frame: 1035 is processed.
# ----------------------
# Frame: 1036 is processed.
# ----------------------
# Frame: 1037 is processed.
# ----------------------
# Frame: 1038 is processed.
# ----------------------
# Frame: 1039 is processed.
# ----------------------
# Frame: 1040 is processed.
# ----------------------
# Frame: 1041 is processed.
# ----------------------
# Frame: 1042 is processed.
# ----------------------
# Frame: 1043 is processed.
# ----------------------
# Frame: 1044 is processed.
# ----------------------
# Frame: 1045 is processed.
# ----------------------
# Frame: 1046 is processed.
# ----------------------
# Frame: 1047 is processed.
# ----------------------
# Frame: 1048 is processed.
# ----------------------
# Frame: 1049 is processed.
# ----------------------
# Frame: 1050 is processed.
# ----------------------
# Frame: 1051 is processed.
# ----------------------
# Frame: 1052 is processed.
# ----------------------
# Frame: 1053 is processed.
# ----------------------
# Frame: 1054 is processed.
# ----------------------
# Frame: 1055 is processed.
# ----------------------
# Frame: 1056 is processed.
# ----------------------
# Frame: 1057 is processed.
# ----------------------
# Frame: 1058 is processed.
# ----------------------
# Frame: 1059 is processed.
# ----------------------
# Frame: 1060 is processed.
# ----------------------
# Frame: 1061 is processed.
# ----------------------
# Frame: 1062 is processed.
# ----------------------
# Frame: 1063 is processed.
# ----------------------
# Frame: 1064 is processed.
# ----------------------
# Frame: 1065 is processed.
# ----------------------
# Frame: 1066 is processed.
# ----------------------
# Frame: 1067 is processed.
# ----------------------
# Frame: 1068 is processed.
# ----------------------
# Frame: 1069 is processed.
# ----------------------
# Frame: 1070 is processed.
# ----------------------
# Frame: 1071 is processed.
# ----------------------
# Frame: 1072 is processed.
# ----------------------
# Frame: 1073 is processed.
# ----------------------
# Frame: 1074 is processed.
# ----------------------
# Frame: 1075 is processed.
# ----------------------
# Frame: 1076 is processed.
# ----------------------
# Frame: 1077 is processed.
# ----------------------
# Frame: 1078 is processed.
# ----------------------
# Frame: 1079 is processed.
# ----------------------
# Frame: 1080 is processed.
# ----------------------
# Frame: 1081 is processed.
# ----------------------
# Frame: 1082 is processed.
# ----------------------
# Frame: 1083 is processed.
# ----------------------
# Frame: 1084 is processed.
# ----------------------
# Frame: 1085 is processed.
# ----------------------
# Frame: 1086 is processed.
# ----------------------
# Frame: 1087 is processed.
# ----------------------
# Frame: 1088 is processed.
# ----------------------
# Frame: 1089 is processed.
# ----------------------
# Frame: 1090 is processed.
# ----------------------
# Frame: 1091 is processed.
# ----------------------
# Frame: 1092 is processed.
# ----------------------
# Frame: 1093 is processed.
# ----------------------
# Frame: 1094 is processed.
# ----------------------
# Frame: 1095 is processed.
# ----------------------
# Frame: 1096 is processed.
# ----------------------
# Frame: 1097 is processed.
# ----------------------
# Frame: 1098 is processed.
# ----------------------
# Frame: 1099 is processed.
# ----------------------
# Frame: 1100 is processed.
# ----------------------
# Frame: 1101 is processed.
# ----------------------
# Frame: 1102 is processed.
# ----------------------
# Frame: 1103 is processed.
# ----------------------
# Frame: 1104 is processed.
# ----------------------
# Frame: 1105 is processed.
# ----------------------
# Frame: 1106 is processed.
# ----------------------
# Frame: 1107 is processed.
# ----------------------
# Frame: 1108 is processed.
# ----------------------
# Frame: 1109 is processed.
# ----------------------
# Frame: 1110 is processed.
# ----------------------
# Frame: 1111 is processed.
# ----------------------
# Frame: 1112 is processed.
# ----------------------
# Frame: 1113 is processed.
# ----------------------
# Frame: 1114 is processed.
# ----------------------
# Frame: 1115 is processed.
# ----------------------
# Frame: 1116 is processed.
# ----------------------
# Frame: 1117 is processed.
# ----------------------
# Frame: 1118 is processed.
# ----------------------
# Frame: 1119 is processed.
# ----------------------
# Frame: 1120 is processed.
# ----------------------
# Frame: 1121 is processed.
# ----------------------
# Frame: 1122 is processed.
# ----------------------
# Frame: 1123 is processed.
# ----------------------
# Frame: 1124 is processed.
# ----------------------
# Frame: 1125 is processed.
# ----------------------
# Your processed video WITHOUT music is saved at: video_out/dior_box_NO_music_center.mp4
# Rendering Video-detection is finished in 1.6 minutes.
# chunk:  18%|█▊        | 174/994 [00:00<00:00, 1725.45it/s, now=None]
# Moviepy - Building video video_out/dior_box_music_center.mp4.
# MoviePy - Writing audio in dior_box_music_centerTEMP_MPY_wvf_snd.mp3
# t:   4%|▎         | 41/1125 [00:00<00:02, 404.03it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video video_out/dior_box_music_center.mp4
# Moviepy - Done !
# Moviepy - video ready video_out/dior_box_music_center.mp4
# Your combined video with music is saved at: video_out/dior_box_music_center.mp4
